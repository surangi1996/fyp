# %%
from PIL import Image

# %%
pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\acer\anaconda3\envs\nlp\lib\site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in c:\users\acer\appdata\roaming\python\python310\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\acer\anaconda3\envs\nlp\lib\site-packages (from pytesseract) (9.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\acer\appdata\roaming\python\python310\site-packages (from packaging>=21.3->pytesseract) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pytesseract import pytesseract
from pytesseract import Output
import cv2

# %%
import PIL.Image

# %%
pip install tesseract
# Out:
# Requirement already satisfied: tesseract in c:\users\acer\anaconda3\envs\nlp\lib\site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
path_to_tesseract = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
# path_to_tesseract = r"C:\Program Files\Tesseract-OCR"
image_path = r"C:\Users\Acer\Downloads\fyp\image.jpg"

img = Image.open(image_path)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=189x267>

# %%
img1 = cv2.imread(image_path)

# %%
myconfig = r"--psm 11 --oem 3"

text = pytesseract.image_to_string(img, config=myconfig)

# %%
text
# Out:
# 'CRICKET\n\nCHAMPIONSHIP\n\nre\n\nEg\n\n=e\n\nJULY 10\n\nll\n\nS\n'

# %%
data = pytesseract.image_to_data(img1, config=myconfig, output_type=Output.DICT)

# %%
amount_boxes = len(data['text'])

# %%
for i in range(amount_boxes):
    if float(data['conf'][i]) > 80:
        (x, y, width, height) = (data['left'][i], data['top'][i], data['width'][i], data['height'][i])
        img1 = cv2.rectangle(img1, (x, y), (x+width, y+height), (0,255,0), 2)
        img1 = cv2.putText(img1, data['text'][i], (x, y+height+20), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0),2, cv2.LINE_AA)

# %%
print(data['text'])
# Out:
# ['', '', '', '', 'CRICKET', 'if', '', '', '', 'ae', '', '', '', 'E', '', '', '', 'iy', '', '', '', 'JULY', '10', '', '', '', '(iy', '', '', '', '1)', '', '', '', 'Ss']

# %%
cv2.imshow("image", img1)
cv2.waitKey(0)
# Out:
# -1
